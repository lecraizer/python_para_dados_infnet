# %% [markdown]
# ## Exercício 1 — Soma por categoria
#
# Dado a lista de vendas abaixo, calcule o total vendido por categoria.

# %%
vendas = [
    {"categoria": "roupa", "valor": 100},
    {"categoria": "comida", "valor": 50},
    {"categoria": "roupa", "valor": 70}
]

# Seu código aqui

# %% [markdown]
# ## Exercício 2 — Palavra mais frequente
#
# Conte a frequência de cada palavra na lista e encontre a mais frequente.

# %%
palavras = ["a", "b", "a", "c", "b", "a"]

# Seu código aqui

# %% [markdown]
# ## Exercício 3 — Produto mais caro por categoria
#
# Encontre o produto mais caro em cada categoria.

# %%
produtos = [
    {"nome": "camisa", "categoria": "roupa", "preco": 50},
    {"nome": "calça", "categoria": "roupa", "preco": 120},
    {"nome": "pizza", "categoria": "comida", "preco": 40}
]

# Seu código aqui

# %% [markdown]
# ## Exercício 4 — Normalização de dados
#
# Normalize os nomes (remova espaços e padronize capitalização) e some os valores de chaves duplicadas.

# %%
dados = {
    "ana": 10,
    "Ana ": 8,
    " BRUNO": 7,
    "bruno": 9
}

# Seu código aqui

# %% [markdown]
# ## Exercício 5 — Histórico de movimentos
#
# Agrupe os valores por pessoa a partir da lista de movimentos abaixo.

# %%
movimentos = [
    {"pessoa": "Ana", "valor": 200},
    {"pessoa": "Bruno", "valor": 150},
    {"pessoa": "Ana", "valor": 80},
    {"pessoa": "Bruno", "valor": 60}
]

# Seu código aqui
